# %%
run /home/sovis2016/tb_test/tf_20161130_2/linear_regression.py
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# (0, array([-0.13212271], dtype=float32), array([ 0.3031711], dtype=float32))
# (0, 0.016710913)
# (1, array([-0.06306406], dtype=float32), array([ 0.30210236], dtype=float32))
# (1, 0.0086181238)
# (2, array([-0.01496309], dtype=float32), array([ 0.30139038], dtype=float32))
# (2, 0.0046920273)
# (3, array([ 0.01854004], dtype=float32), array([ 0.30089444], dtype=float32))
# (3, 0.0027873393)
# (4, array([ 0.04187552], dtype=float32), array([ 0.30054903], dtype=float32))
# (4, 0.0018633076)
# (5, array([ 0.05812908], dtype=float32), array([ 0.30030844], dtype=float32))
# (5, 0.0014150268)
# (6, array([ 0.06944995], dtype=float32), array([ 0.30014086], dtype=float32))
# (6, 0.0011975502)
# (7, array([ 0.07733512], dtype=float32), array([ 0.30002412], dtype=float32))
# (7, 0.0010920446)

# %%
run /home/sovis2016/tb_test/tf_20161130_2/a_cnn.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/sovis2016/tb_test/tf_20161130_2/a_cnn.py in <module>()
#      71 # -> 함수 작성 끝! 이제 학습을 돌려보면 된다.
#      72
# ---> 73 init = tf.initialize_all_varialbes()
#      74
#      75
#
# AttributeError: 'module' object has no attribute 'initialize_all_varialbes'

# %%
run /home/sovis2016/tb_test/tf_20161130_2/a_cnn.py
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /home/sovis2016/tb_test/tf_20161130_2/a_cnn.py in <module>()
#      90         # 지정된 횟수만큼 학습한다.
#      91     for epoch in range(training_epochs):
# ---> 92         sess.run(train_step, feed_dict={X: tc, Y: td})
#      93
#      94         point_x.append(epoch)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
# ...
