# %%
# %load_ext autoreload

# %autoreload 2

# %%
import librosa.util
import librosa.effects
import librosa
import matplotlib.pyplot as plt
# %matplotlib nbagg
import librosa.display
import numpy as np

# %%
y, sr = librosa.load('/home/sovis2016/asd/7/15419__pagancow__dorm-door-opening.wav',
                     sr=None, duration=30, offset=30)

# %%
#y = librosa.util.pad_center(y, size=len(y) + 5 * sr)

# %%
hop_length = 512

intervals = librosa.effects.split(y, hop_length=hop_length)

interval_times = librosa.samples_to_time(intervals, sr=sr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-3cc426db7cbd> in <module>()
#       1 hop_length = 512
#       2
# ----> 3 intervals = librosa.effects.split(y, hop_length=hop_length)
#       4
#       5 interval_times = librosa.samples_to_time(intervals, sr=sr)
#
# AttributeError: 'module' object has no attribute 'split'

# %%
interval_times
# Out:
# array([[  3.71519274,   6.58285714],
#        [  7.44199546,  10.43736961],
#        [ 11.74929705,  14.75628118],
#        [ 15.81278912,  18.72689342],
#        [ 19.69052154,  22.75555556],
#        [ 23.73079365,  26.69133787],
#        [ 27.65496599,  30.55746032],
#        [ 31.45142857,  32.50793651]])

# %%
plt.figure()
librosa.display.waveplot(y, sr=sr)

for ival in interval_times:
    plt.axvspan(ival[0], ival[1], ymin=-1, ymax=1, alpha=0.25, color='r')
# Out:
# <img src="data:image/png;base64,...">
